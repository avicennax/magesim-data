# %%
import json
import pandas as pd

from gql import gql, Client
from gql.transport.aiohttp import AIOHTTPTransport

# %%
with open("../.oauth", "r") as fobj:
     cid, secret = [s.rstrip('\n') for s in fobj.readlines()]

# %%
# %%capture output
# %%bash -s "$cid" "$secret"
curl -u $1:$2 -d grant_type=client_credentials https://classic.warcraftlogs.com/oauth/token

# %%
token = json.loads(output.stdout)['access_token']

transport = AIOHTTPTransport(
    url='https://classic.warcraftlogs.com/api/v2/client', 
    headers={'Authorization': 'Bearer ' + token}, 
    timeout=120
)
client = Client(transport=transport, fetch_schema_from_transport=True)

# %%
zone_id = 1007
encounter_id = 652
start_time = 0
limit = 10
pages = 1
page = 1

data = {}

query = gql("""
    query ($zoneID: Int!, $encounterID: Int!, $startTime: Float!, $limit: Int!, $page: Int!) {
      reportData {
        reports(zoneID: $zoneID, guildServerRegion: "US", startTime: $startTime, limit: $limit, page: $page) {
          data {
            events(encounterID: $encounterID, startTime: 0, endTime: 999999999, limit: 20000) {
               data
            }
          }
        }
      }
    }
""")

res = await client.execute_async(query, {
    "zoneID": zone_id,
    "encounterID": encounter_id,
    "startTime": start_time,
    "limit": limit,
    "page": page,
})

# %% [markdown]
# https://tbc.wowhead.com/spell=31687/summon-water-elemental
#
# https://tbc.wowhead.com/spell=31707/waterbolt

# %%
data = res["reportData"]["reports"]["data"]

# %%
set([event["type"] for event in data[0]["events"]["data"]])
# Out:
# {'absorbed',
#  'applybuff',
#  'applybuffstack',
#  'applydebuff',
#  'applydebuffstack',
#  'begincast',
#  'cast',
#  'combatantinfo',
#  'damage',
#  'death',
#  'dispel',
#  'encounterend',
#  'encounterstart',
#  'energize',
#  'extraattacks',
#  'heal',
#  'refreshbuff',
#  'refreshdebuff',
#  'removebuff',
#  'removebuffstack',
#  'removedebuff',
#  'removedebuffstack',
#  'summon'}

# %%
water_infos = []
for i, report in enumerate(data):
    events = report["events"]["data"]
    for event in events:
        if event["type"] == "combatantinfo" and event["sourceID"] == 25:
            print(i, event)
# Out:
# 1 {'timestamp': 571786, 'type': 'combatantinfo', 'sourceID': 25, 'gear': [{'id': 16939, 'quality': 4, 'icon': 'inv_helmet_05.jpg', 'itemLevel': 76, 'permanentEnchant': 2586}, {'id': 35507, 'quality': 4, 'icon': 'inv_jewelry_necklace_18.jpg', 'itemLevel': 110}, {'id': 27801, 'quality': 3, 'icon': 'inv_shoulder_23.jpg', 'itemLevel': 115, 'permanentEnchant': 2606, 'gems': [{'id': 24028, 'itemLevel': 70, 'icon': 'inv_jewelcrafting_livingruby_03.jpg'}, {'id': 24028, 'itemLevel': 70, 'icon': 'inv_jewelcrafting_livingruby_03.jpg'}]}, {'id': 0, 'quality': 1, 'icon': 'inv_axe_02.jpg', 'itemLevel': 0}, {'id': 28186, 'quality': 3, 'icon': 'inv_chest_leather_04.jpg', 'itemLevel': 112, 'gems': [{'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}, {'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}, {'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}]}, {'id': 31293, 'quality': 3, 'icon': 'inv_belt_31.jpg', 'itemLevel': 112}, {'id': 27874, 'quality': 3, 'icon': 'inv_pants_03.jpg', 'itemLevel': 115, 'permanentEnchant': 2586}, {'id': 25686, 'quality': 3, 'icon': 'inv_boots_cloth_05.jpg', 'itemLevel': 112, 'gems': [{'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}, {'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}]}, {'id': 16935, 'quality': 4, 'icon': 'inv_bracer_17.jpg', 'itemLevel': 76, 'permanentEnchant': 1593}, {'id': 27474, 'quality': 3, 'icon': 'inv_gauntlets_10.jpg', 'itemLevel': 115, 'gems': [{'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}, {'id': 28595, 'itemLevel': 60, 'icon': 'inv_misc_gem_bloodgem_02.jpg'}]}, {'id': 17063, 'quality': 4, 'icon': 'inv_jewelry_ring_15.jpg', 'itemLevel': 78}, {'id': 19384, 'quality': 4, 'icon': 'inv_jewelry_ring_41.jpg', 'itemLevel': 83}, {'id': 28041, 'quality': 3, 'icon': 'inv_datacrystal06.jpg', 'itemLevel': 88}, {'id': 18473, 'quality': 3, 'icon': 'inv_jewelry_talisman_10.jpg', 'itemLevel': 62}, {'id': 28032, 'quality': 3, 'icon': 'inv_misc_cape_05.jpg', 'itemLevel': 97}, {'id': 27903, 'quality': 3, 'icon': 'inv_spear_08.jpg', 'itemLevel': 115, 'permanentEnchant': 2670, 'temporaryEnchant': 2639}, {'id': 0, 'quality': 1, 'icon': 'inv_axe_02.jpg', 'itemLevel': 0}, {'id': 31303, 'quality': 3, 'icon': 'inv_weapon_bow_04.jpg', 'itemLevel': 115, 'permanentEnchant': 2722}, {'id': 28788, 'quality': 2, 'icon': 'inv_shirt_guildtabard_01.jpg', 'itemLevel': 60}], 'auras': [{'source': 25, 'ability': 33261, 'stacks': 1, 'icon': 'spell_misc_food.jpg', 'name': 'Well Fed'}, {'source': 4, 'ability': 25895, 'stacks': 1, 'icon': 'spell_holy_greaterblessingofsalvation.jpg', 'name': 'Greater Blessing of Salvation'}, {'source': 4, 'ability': 20218, 'stacks': 1, 'icon': 'spell_holy_mindvision.jpg', 'name': 'Sanctity Aura'}, {'source': 7, 'ability': 25312, 'stacks': 1, 'icon': 'spell_holy_divinespirit.jpg', 'name': 'Divine Spirit'}, {'source': 25, 'ability': 28497, 'stacks': 1, 'icon': 'inv_potion_162.jpg', 'name': 'Mighty Agility'}], 'expansion': 'tbc', 'faction': 1, 'specID': 0, 'strength': 79, 'agility': 612, 'stamina': 443, 'intellect': 215, 'spirit': 185, 'dodge': 0, 'parry': 0, 'block': 0, 'armor': 5091, 'critMelee': 87, 'critRanged': 87, 'critSpell': 0, 'hasteMelee': 0, 'hasteRanged': 0, 'hasteSpell': 0, 'hitMelee': 131, 'hitRanged': 131, 'hitSpell': 0, 'expertise': 0, 'resilienceCritTaken': 0, 'resilienceDamageTaken': 0, 'talents': [{'id': 41, 'icon': 'inv_axe_02.jpg'}, {'id': 20, 'icon': 'inv_axe_02.jpg'}, {'id': 0, 'icon': 'inv_axe_02.jpg'}], 'pvpTalents': [], 'customPowerSet': [], 'secondaryCustomPowerSet': [], 'tertiaryCustomPowerSet': []}

# %%
water_summs = []
for i, report in enumerate(data):
    events = report["events"]["data"]
    for event in events:
        if event["type"] == "summon" and event["abilityGameID"] == 31687:
            water_summs.append((i, event))

# %%
water_summs
# Out:
# [(4,
#   {'timestamp': 589821,
#    'type': 'summon',
#    'sourceID': 11,
#    'targetID': 25,
#    'targetInstance': 1,
#    'abilityGameID': 31687}),
#  (4,
#   {'timestamp': 695918,
#    'type': 'summon',
#    'sourceID': 11,
#    'targetID': 25,
#    'targetInstance': 2,
#    'abilityGameID': 31687}),
#  (6,
#   {'timestamp': 461893,
#    'type': 'summon',
#    'sourceID': 5,
#    'targetID': 26,
#    'abilityGameID': 31687}),
#  (6,
#   {'timestamp': 462404,
#    'type': 'summon',
#    'sourceID': 13,
#    'targetID': 37,
#    'abilityGameID': 31687})]

# %%
# Looking at a deep frostie boi
report_4 = data[4]["events"]["data"]
for event in report_4:
    if event["type"] == "combatantinfo" and event["sourceID"] == 11:
        frost_mage = event

# %%
pd.json_normalize(frost_mage, sep="_").iloc[0]
# Out:
# timestamp                                                             581108
# type                                                           combatantinfo
# sourceID                                                                  11
# gear                       [{'id': 29076, 'quality': 4, 'icon': 'inv_helm...
# auras                      [{'source': 10, 'ability': 27127, 'stacks': 1,...
# expansion                                                                tbc
# faction                                                                    0
# specID                                                                     0
# strength                                                                  46
# agility                                                                   51
# stamina                                                                  549
# intellect                                                                505
# spirit                                                                   220
# dodge                                                                      0
# parry                                                                      0
# block                                                                      0
# armor                                                                   2027
# critMelee                                                                  0
# critRanged                                                                 0
# critSpell                                                                214
# hasteMelee                                                                 0
# hasteRanged                                                                0
# hasteSpell                                                                 0
# hitMelee                                                                   0
# hitRanged                                                                  0
# hitSpell                                                                 165
# expertise                                                                  0
# resilienceCritTaken                                                        0
# resilienceDamageTaken                                                      0
# talents                    [{'id': 11, 'icon': 'spell_frost_frostbolt02.j...
# pvpTalents                                                                []
# customPowerSet                                                            []
# secondaryCustomPowerSet                                                   []
# tertiaryCustomPowerSet                                                    []
# Name: 0, dtype: object

# %% [markdown]
# Nice, we can get hit, crit and int. SP doesn't seem readily computable.

# %%
frost_mage["gear"]
# Out:
# [{'id': 29076,
#   'quality': 4,
#   'icon': 'inv_helmet_84.jpg',
#   'itemLevel': 120,
#   'permanentEnchant': 3002,
#   'gems': [{'id': 34220,
#     'itemLevel': 70,
#     'icon': 'inv_misc_gem_diamond_07.jpg'},
#    {'id': 24056,
#     'itemLevel': 70,
#     'icon': 'inv_jewelcrafting_nightseye_03.jpg'}]},
#  {'id': 28134,
#   'quality': 3,
#   'icon': 'inv_jewelry_necklace_27.jpg',
#   'itemLevel': 112},
#  {'id': 27796,
#   'quality': 3,
#   'icon': 'inv_shoulder_22.jpg',
#   'itemLevel': 115,
#   'permanentEnchant': 2994,
#   'gems': [{'id': 30608,
#     'itemLevel': 70,
#     'icon': 'inv_jewelcrafting_talasite_03.jpg'},
#    {'id': 30605,
#     'itemLevel': 70,
#     'icon': 'inv_jewelcrafting_talasite_03.jpg'}]},
#  {'id': 6096, 'quality': 2, 'icon': 'inv_shirt_01.jpg', 'itemLevel': 1},
#  {'id': 27799,
#   'quality': 3,
#   'icon': 'inv_chest_cloth_18.jpg',
#   'itemLevel': 115,
#   'permanentEnchant': 3150},
#  {'id': 28654, 'quality': 4, 'icon': 'inv_belt_03.jpg', 'itemLevel': 115},
#  {'id': 27907,
#   'quality': 3,
#   'icon': 'inv_pants_cloth_17.jpg',
#   'itemLevel': 115,
#   'permanentEnchant': 2747},
#  {'id': 29242,
#   'quality': 4,
#   'icon': 'inv_boots_cloth_11.jpg',
#   'itemLevel': 110,
#   'permanentEnchant': 2841},
#  {'id': 28174,
#   'quality': 3,
#   'icon': 'inv_bracer_07.jpg',
#   'itemLevel': 115,
#   'permanentEnchant': 369,
#   'gems': [{'id': 23101,
#     'itemLevel': 60,
#     'icon': 'inv_misc_gem_flamespessarite_02.jpg'}]},
#  {'id': 29080,
#   'quality': 4,
#   'icon': 'inv_gauntlets_47.jpg',
#   'itemLevel': 120,
#   'permanentEnchant': 2935},
#  {'id': 28227,
#   'quality': 3,
#   'icon': 'inv_jewelry_ring_63.jpg',
#   'itemLevel': 115},
#  {'id': 29172,
#   'quality': 4,
#   'icon': 'inv_jewelry_ring_51naxxramas.jpg',
#   'itemLevel': 105},
#  {'id': 27683,
#   'quality': 3,
#   'icon': 'inv_misc_gem_pearl_01.jpg',
#   'itemLevel': 115},
#  {'id': 29370,
#   'quality': 4,
#   'icon': 'inv_weapon_shortblade_23.jpg',
#   'itemLevel': 110},
#  {'id': 22731,
#   'quality': 4,
#   'icon': 'inv_misc_cape_18.jpg',
#   'itemLevel': 88,
#   'permanentEnchant': 2621},
#  {'id': 27842,
#   'quality': 3,
#   'icon': 'inv_staff_45.jpg',
#   'itemLevel': 115,
#   'temporaryEnchant': 2628},
#  {'id': 0, 'quality': 1, 'icon': 'inv_axe_02.jpg', 'itemLevel': 0},
#  {'id': 29350,
#   'quality': 4,
#   'icon': 'inv_wand_1h_stratholme_d_01.jpg',
#   'itemLevel': 110},
#  {'id': 31804,
#   'quality': 2,
#   'icon': 'inv_shirt_guildtabard_01.jpg',
#   'itemLevel': 20}]

# %%
waterbolts = []
for report in data:
    events = report["events"]["data"]
    for event in events:
        if event["type"] == "damage" and event["abilityGameID"] == 31707:
            waterbolts.append(event)

# %%
waterbolts
# Out:
# [{'timestamp': 594283,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1051,
#   'unmitigatedAmount': 910},
#  {'timestamp': 597254,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1056,
#   'unmitigatedAmount': 914},
#  {'timestamp': 600440,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 997,
#   'unmitigatedAmount': 863},
#  {'timestamp': 603756,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 991,
#   'unmitigatedAmount': 858},
#  {'timestamp': 606517,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1045,
#   'unmitigatedAmount': 905},
#  {'timestamp': 609965,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 791,
#   'mitigated': 121,
#   'unmitigatedAmount': 912,
#   'resisted': 228},
#  {'timestamp': 614092,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 757,
#   'mitigated': 116,
#   'unmitigatedAmount': 873,
#   'resisted': 218},
#  {'timestamp': 617550,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 958,
#   'unmitigatedAmount': 829},
#  {'timestamp': 620769,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 949,
#   'unmitigatedAmount': 821},
#  {'timestamp': 623420,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 731,
#   'mitigated': 112,
#   'unmitigatedAmount': 843,
#   'resisted': 211},
#  {'timestamp': 625785,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 940,
#   'unmitigatedAmount': 813},
#  {'timestamp': 629355,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 971,
#   'unmitigatedAmount': 840},
#  {'timestamp': 633308,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 1,
#   'targetID': 32,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1002,
#   'unmitigatedAmount': 866},
#  {'timestamp': 700687,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 2,
#   'amount': 1384,
#   'unmitigatedAmount': 838},
#  {'timestamp': 703877,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 707033,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 710004,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 923,
#   'unmitigatedAmount': 838},
#  {'timestamp': 713503,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 716737,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 719687,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 916,
#   'unmitigatedAmount': 832},
#  {'timestamp': 723225,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 726193,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 948,
#   'unmitigatedAmount': 862},
#  {'timestamp': 729443,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 475,
#   'mitigated': 387,
#   'unmitigatedAmount': 862,
#   'resisted': 431},
#  {'timestamp': 732657,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 949,
#   'unmitigatedAmount': 863},
#  {'timestamp': 735901,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 959,
#   'unmitigatedAmount': 872},
#  {'timestamp': 739142,
#   'type': 'damage',
#   'sourceID': 25,
#   'sourceInstance': 2,
#   'targetID': 37,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 706,
#   'mitigated': 149,
#   'unmitigatedAmount': 855,
#   'resisted': 214},
#  {'timestamp': 465724,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 466481,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 965,
#   'unmitigatedAmount': 877},
#  {'timestamp': 468776,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 958,
#   'unmitigatedAmount': 871},
#  {'timestamp': 469001,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 972,
#   'unmitigatedAmount': 884},
#  {'timestamp': 472006,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 958,
#   'unmitigatedAmount': 871},
#  {'timestamp': 472231,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 756,
#   'mitigated': 159,
#   'unmitigatedAmount': 915,
#   'resisted': 229},
#  {'timestamp': 475242,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 965,
#   'unmitigatedAmount': 877},
#  {'timestamp': 475571,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 478471,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 969,
#   'unmitigatedAmount': 880},
#  {'timestamp': 478717,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 2,
#   'amount': 1428,
#   'unmitigatedAmount': 865},
#  {'timestamp': 481719,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 947,
#   'unmitigatedAmount': 860},
#  {'timestamp': 481962,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1014,
#   'unmitigatedAmount': 921},
#  {'timestamp': 487601,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 740,
#   'mitigated': 156,
#   'unmitigatedAmount': 896,
#   'resisted': 224},
#  {'timestamp': 488642,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 993,
#   'unmitigatedAmount': 903},
#  {'timestamp': 490200,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 491063,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1005,
#   'unmitigatedAmount': 914},
#  {'timestamp': 492640,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 493511,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 975,
#   'unmitigatedAmount': 886},
#  {'timestamp': 495054,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 495934,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1023,
#   'unmitigatedAmount': 930},
#  {'timestamp': 497314,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 996,
#   'unmitigatedAmount': 905},
#  {'timestamp': 498345,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 1,
#   'amount': 1033,
#   'unmitigatedAmount': 938},
#  {'timestamp': 499926,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 500854,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 502161,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 2,
#   'amount': 1511,
#   'unmitigatedAmount': 915},
#  {'timestamp': 503199,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 2,
#   'amount': 1612,
#   'unmitigatedAmount': 977},
#  {'timestamp': 504778,
#   'type': 'damage',
#   'sourceID': 37,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 14,
#   'amount': 0},
#  {'timestamp': 505636,
#   'type': 'damage',
#   'sourceID': 26,
#   'targetID': 36,
#   'abilityGameID': 31707,
#   'hitType': 16,
#   'amount': 785,
#   'mitigated': 166,
#   'unmitigatedAmount': 951,
#   'resisted': 238}]

# %% [markdown]
# Looks like the sourceID of the summon is the mage and the targetID is the water elemental - the waterbolts sourceIDs match to the summoned elementals. This actually looks really manageable - for each fight we can tag each water elemental to a mage, then we just need to determine if water elemental got drums / hero. We might be able to pick that explicit via an applybuff event, if not we'll just have to guess.

# %%
buffs = []
idx = [((25,), 4), ((26, 37), 6)]

for target_ids, index in idx:
    events = data[index]["events"]["data"]
    for event in events:
        if event["type"] in ["applybuff", "removebuff"] and event["targetID"] in target_ids:
            buffs.append(event)

# %%
buffs
# Out:
# [{'timestamp': 703650,
#   'type': 'applybuff',
#   'sourceID': 12,
#   'targetID': 25,
#   'targetInstance': 2,
#   'abilityGameID': 35476},
#  {'timestamp': 733651,
#   'type': 'removebuff',
#   'sourceID': 12,
#   'targetID': 25,
#   'targetInstance': 2,
#   'abilityGameID': 35476},
#  {'timestamp': 467037,
#   'type': 'applybuff',
#   'sourceID': 5,
#   'targetID': 26,
#   'abilityGameID': 28142},
#  {'timestamp': 467037,
#   'type': 'applybuff',
#   'sourceID': 5,
#   'targetID': 37,
#   'abilityGameID': 28142},
#  {'timestamp': 483789,
#   'type': 'applybuff',
#   'sourceID': 6,
#   'targetID': 26,
#   'abilityGameID': 2825},
#  {'timestamp': 483789,
#   'type': 'applybuff',
#   'sourceID': 6,
#   'targetID': 37,
#   'abilityGameID': 2825},
#  {'timestamp': 489795,
#   'type': 'applybuff',
#   'sourceID': 6,
#   'targetID': 26,
#   'abilityGameID': 35475},
#  {'timestamp': 489795,
#   'type': 'applybuff',
#   'sourceID': 6,
#   'targetID': 37,
#   'abilityGameID': 35475},
#  {'timestamp': 507056,
#   'type': 'removebuff',
#   'sourceID': 5,
#   'targetID': 26,
#   'abilityGameID': 28142},
#  {'timestamp': 507056,
#   'type': 'removebuff',
#   'sourceID': 6,
#   'targetID': 26,
#   'abilityGameID': 2825},
#  {'timestamp': 507056,
#   'type': 'removebuff',
#   'sourceID': 6,
#   'targetID': 26,
#   'abilityGameID': 35475},
#  {'timestamp': 507879,
#   'type': 'removebuff',
#   'sourceID': 5,
#   'targetID': 37,
#   'abilityGameID': 28142},
#  {'timestamp': 507879,
#   'type': 'removebuff',
#   'sourceID': 6,
#   'targetID': 37,
#   'abilityGameID': 2825},
#  {'timestamp': 507879,
#   'type': 'removebuff',
#   'sourceID': 6,
#   'targetID': 37,
#   'abilityGameID': 35475}]

# %% [markdown]
# - https://tbc.wowhead.com/spell=35476/drums-of-battle
# - https://www.wowhead.com/spell=28142/power-of-the-guardian
#
# Nice - no https://tbc.wowhead.com/spell=32182/heroism but from this sample I can assume I can infer their buff by looking at the events exactly.
#
#
# ### TODO
#
# - Create module for code reuse.
# - Pull out client auth code into module.
# - Create function for loop snippet above.
